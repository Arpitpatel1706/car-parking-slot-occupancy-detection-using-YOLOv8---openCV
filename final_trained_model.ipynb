# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\hp\Desktop\car_parking_slot_occupancy_detection_using_yolov8

# %%
# Pip install method (recommended)


# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.115 🚀 Python-3.11.4 torch-2.0.1+cpu CPU
# Setup complete ✅ (8 CPUs, 15.8 GB RAM, 172.0/236.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tUZCeeGNLljUnpXXsngy")
project = rf.workspace("swastik-abhijit-patra-zlamm").project("real-time-parking-lot-vehicle-detection")
dataset = project.version(1).download("yolov8")
# Out:
# [WinError 2] The system cannot find the file specified: 'c:\\Users\\hp\\Desktop\\car_parking_slot_occupancy_detection_using_yolov8/datasets'
# c:\Users\hp\Desktop\car_parking_slot_occupancy_detection_using_yolov8
# The syntax of the command is incorrect.
# Requirement already satisfied: roboflow in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.0.9)
# Requirement already satisfied: certifi==2022.12.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: chardet==4.0.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.24.3)
# Requirement already satisfied: opencv-python>=4.1.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (9.5.0)
# Requirement already satisfied: pyparsing==2.4.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.4.7)
# Requirement already satisfied: python-dateutil in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.0.3)
# Requirement already satisfied: wget in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (3.2)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (6.0)
# Requirement already satisfied: requests-toolbelt in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->roboflow) (4.39.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->roboflow) (3.1.0)
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.115, to fix: `pip install ultralytics<=8.0.20`
# Downloading Dataset Version Zip in Real-time-parking-lot-vehicle-detection-1 to yolov8: 100% [153501374 / 153501374] bytes
# Extracting Dataset Version Zip to Real-time-parking-lot-vehicle-detection-1 in yolov8:: 100%|██████████| 3846/3846 [00:05<00:00, 703.91it/s]

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8m.pt data=r'C:\Users\hp\Desktop\car_parking_slot_occupancy_detection_using_yolov8\Real-time-parking-lot-vehicle-detection-1\data.yaml' epochs=30 imgsz=640 plots=True
# Out:
# c:\Users\hp\Desktop\car_parking_slot_occupancy_detection_using_yolov8
# ^C
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %cd {HOME}
Image(filename=f'/content/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# C:\Users\hp\Desktop\smart_parking_system
# Traceback (most recent call last):
#   File "C:\Users\hp\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\hp\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\hp\anaconda3\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\hp\anaconda3\lib\site-packages\ultralytics\yolo\cfg\__init__.py", line 367, in entrypoint
#     model = YOLO(model, task=task)
#   File "C:\Users\hp\anaconda3\lib\site-packages\ultralytics\yolo\engine\model.py", line 107, in __init__
#     self._load(model, task)
#   File "C:\Users\hp\anaconda3\lib\site-packages\ultralytics\yolo\engine\model.py", line 156, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "C:\Users\hp\anaconda3\lib\site-packages\ultralytics\nn\tasks.py", line 441, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "C:\Users\hp\anaconda3\lib\site-packages\ultralytics\nn\tasks.py", line 381, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
#   File "C:\Users\hp\anaconda3\lib\site-packages\torch\serialization.py", line 791, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "C:\Users\hp\anaconda3\lib\site-packages\torch\serialization.py", line 271, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "C:\Users\hp\anaconda3\lib\site-packages\torch\serialization.py", line 252, in __init__
#     super().__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\hp\\Desktop\\smart_parking_system\\runs\\detect\\train\\weights\\best.pt'

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/smart_parking_system/parking1.mp4 save=True
# Out:
# C:\Users\hp\Desktop\smart_parking_system
# Traceback (most recent call last):
#   File "C:\Users\hp\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\hp\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\hp\anaconda3\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\hp\anaconda3\lib\site-packages\ultralytics\yolo\cfg\__init__.py", line 367, in entrypoint
#     model = YOLO(model, task=task)
#   File "C:\Users\hp\anaconda3\lib\site-packages\ultralytics\yolo\engine\model.py", line 107, in __init__
#     self._load(model, task)
#   File "C:\Users\hp\anaconda3\lib\site-packages\ultralytics\yolo\engine\model.py", line 156, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "C:\Users\hp\anaconda3\lib\site-packages\ultralytics\nn\tasks.py", line 441, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "C:\Users\hp\anaconda3\lib\site-packages\ultralytics\nn\tasks.py", line 381, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
#   File "C:\Users\hp\anaconda3\lib\site-packages\torch\serialization.py", line 791, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "C:\Users\hp\anaconda3\lib\site-packages\torch\serialization.py", line 271, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "C:\Users\hp\anaconda3\lib\site-packages\torch\serialization.py", line 252, in __init__
#     super().__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\hp\\Desktop\\smart_parking_system\\runs\\detect\\train\\weights\\best.pt'
